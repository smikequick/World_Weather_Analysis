# %%
# Import the random module
import random

# %%
# Generate random integer between the two values
random.randint(-90, 90)
# Out:
# 67

# %%
# Generate random floating point decimal 
random.random()
# Out:
# 0.8494659172555469

# %%
# Generate a random floating point decimal between the range
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# 25.038845122674918

# %%
# Generate 10 sample latitudes by assign var, gen list, create loop of rand numbers.
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x+=1

# %%
latitudes
# Out:
# [7.11895934746317,
#  -17.876814150832484,
#  -19.450799739518278,
#  5.799770205175386,
#  88.61418816443637,
#  -49.826668568589206,
#  -24.711793673995427,
#  -5.894520689822938,
#  -26.298483539111334,
#  -31.197876268418142]

# %%
random.randrange(-90, 90, step=1)
# Out:
# -83

# %%
random.randrange(-90, 90, step=3)
# Out:
# -45

# %%
random.uniform(-90, 90)
# Out:
# 27.68829252223999

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(low=-90, high=90)
# Out:
# 50.96473144042574

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 12.4 µs ± 8.26 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x+=1
    return latitudes

# Call the function with 1500

# %timeit latitudes(1500)
# Out:
# 1.12 ms ± 5.35 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit latitudes=[]

for x in range(1500):
    print(random.uniform(-90, 90))
# Out:
# 20.1 ns ± 0.0465 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# 15.418211349165816
# -38.562080425932905
# -52.69835625875679
# 84.21594336611204
# -88.88808953342205
# -47.722025834937014
# -64.56453357061913
# 4.891588960590951
# 3.184037021252834
# 35.96924217759846
# -65.99492506089479
# -54.812145671475214
# -32.8923527296058
# -88.83927587463273
# 18.395199480373904
# 18.036460568226943
# 38.894382093336475
# -89.58031499433702
# 4.124506630978786
# 36.108481446157185
# 19.87845011615711
# 3.679563394686042
# 8.068673009087334
# 25.521054005569837
# 30.557265808874533
# -69.52664832299851
# 15.681622977061366
# -80.69431684299175
# 22.306384103378335
# -64.60618880635283
# -3.02625435873297
# 80.75379460151231
# 69.60701618388052
# -3.7319115304947843
# -45.406379038939654
# 20.689091284883077
# 21.536971018282713
# 81.56300169021966
# -56.982957950617546
# -32.354474957710266
# -78.82177186416524
# 35.69773148494298
# 57.377616819896275
# 78.58569569801728
# ...
