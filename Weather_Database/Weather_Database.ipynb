# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip (lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

       # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + city.replace(' ', '+')

    # Log the URL, record, and set numbers and the city.
    print (f'Processing Record {record_count} of Set {set_count} | {city}')

    # Add 1 to the recount count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_desc = city_weather['weather'][0]['description']
       
        
        #Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
#If an error is experience, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-------------------------")
print("Data Retrieval Complete  ")
print("-------------------------")

len(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | daru
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | cangucu
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | copiapo
# Processing Record 8 of Set 1 | egvekinot
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | kyren
# Processing Record 15 of Set 1 | inverell
# Processing Record 16 of Set 1 | sakakah
# Processing Record 17 of Set 1 | bubaque
# Processing Record 18 of Set 1 | tvoroyri
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | lompoc
# Processing Record 21 of Set 1 | hasaki
# Processing Record 22 of Set 1 | narsaq
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | lozovo
# Processing Record 25 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | shitanjing
# Processing Record 30 of Set 1 | saint-pierre
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | columbus
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | fare
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | kununurra
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | yerbogachen
# Processing Record 41 of Set 1 | socorro
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | lata
# Processing Record 44 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 1 | tornio
# Processing Record 46 of Set 1 | christchurch
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | port shepstone
# Processing Record 2 of Set 2 | sorland
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | kavaratti
# Processing Record 8 of Set 2 | grindavik
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | surt
# Processing Record 13 of Set 2 | caravelas
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | naze
# Processing Record 16 of Set 2 | chengdu
# Processing Record 17 of Set 2 | celestun
# Processing Record 18 of Set 2 | mogadishu
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | mega
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | hisai
# Processing Record 24 of Set 2 | ortona
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | mae sai
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | tautira
# Processing Record 29 of Set 2 | yazoo city
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | vrangel
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | quatre cocos
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | anloga
# Processing Record 38 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 2 | illapel
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | chapais
# Processing Record 43 of Set 2 | san vicente
# Processing Record 44 of Set 2 | rikitea
# Processing Record 45 of Set 2 | bor
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | pisco
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | ilmajoki
# Processing Record 1 of Set 3 | leua
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | bud
# Processing Record 4 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | hun
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | road town
# Processing Record 14 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 3 | sergeyevka
# Processing Record 16 of Set 3 | sinnamary
# Processing Record 17 of Set 3 | alyangula
# Processing Record 18 of Set 3 | waingapu
# Processing Record 19 of Set 3 | hami
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | kaeo
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | tessalit
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | mayo
# Processing Record 28 of Set 3 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 29 of Set 3 | erenhot
# Processing Record 30 of Set 3 | winston-salem
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | paz de ariporo
# City not found. Skipping...
# Processing Record 34 of Set 3 | ajdabiya
# Processing Record 35 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 3 | marsh harbour
# Processing Record 37 of Set 3 | bambanglipuro
# Processing Record 38 of Set 3 | stykkisholmur
# Processing Record 39 of Set 3 | padang
# Processing Record 40 of Set 3 | san policarpo
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | bousso
# Processing Record 43 of Set 3 | kraskino
# Processing Record 44 of Set 3 | aschersleben
# Processing Record 45 of Set 3 | khani
# Processing Record 46 of Set 3 | chachapoyas
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | axim
# Processing Record 50 of Set 3 | honningsvag
# Processing Record 1 of Set 4 | yarim
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | kushikino
# Processing Record 4 of Set 4 | ginda
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | kamenka
# Processing Record 9 of Set 4 | mgandu
# Processing Record 10 of Set 4 | lulea
# Processing Record 11 of Set 4 | casper
# Processing Record 12 of Set 4 | great yarmouth
# Processing Record 13 of Set 4 | boguchany
# Processing Record 14 of Set 4 | progreso
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | koumac
# Processing Record 20 of Set 4 | bam
# Processing Record 21 of Set 4 | provideniya
# Processing Record 22 of Set 4 | fortuna
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | bol
# Processing Record 25 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | isla vista
# Processing Record 28 of Set 4 | morros
# Processing Record 29 of Set 4 | katha
# City not found. Skipping...
# Processing Record 30 of Set 4 | baruun-urt
# Processing Record 31 of Set 4 | gobabis
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | sunndalsora
# Processing Record 34 of Set 4 | srednebelaya
# Processing Record 35 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 4 | massaguet
# Processing Record 37 of Set 4 | moron
# Processing Record 38 of Set 4 | maracaju
# Processing Record 39 of Set 4 | puerto ayora
# Processing Record 40 of Set 4 | nyurba
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 4 | saint-francois
# Processing Record 45 of Set 4 | la ligua
# Processing Record 46 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | lagoa
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | san cristobal
# Processing Record 1 of Set 5 | vadso
# Processing Record 2 of Set 5 | volchanets
# Processing Record 3 of Set 5 | acapulco
# Processing Record 4 of Set 5 | chokurdakh
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | popondetta
# Processing Record 7 of Set 5 | klaksvik
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | ayer itam
# City not found. Skipping...
# Processing Record 10 of Set 5 | kuala terengganu
# Processing Record 11 of Set 5 | rogaska slatina
# Processing Record 12 of Set 5 | kahului
# Processing Record 13 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 5 | korla
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | vaasa
# Processing Record 18 of Set 5 | inhambane
# Processing Record 19 of Set 5 | bustamante
# Processing Record 20 of Set 5 | gambissara
# Processing Record 21 of Set 5 | seoul
# Processing Record 22 of Set 5 | todos santos
# Processing Record 23 of Set 5 | alegrete
# Processing Record 24 of Set 5 | olopa
# Processing Record 25 of Set 5 | coahuayana
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 5 | san jose de rio tinto
# Processing Record 28 of Set 5 | shimoda
# Processing Record 29 of Set 5 | carauari
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | aklavik
# Processing Record 32 of Set 5 | manavalakurichi
# Processing Record 33 of Set 5 | hearst
# Processing Record 34 of Set 5 | xiantao
# Processing Record 35 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 5 | filadelfia
# Processing Record 37 of Set 5 | torbay
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | bereda
# Processing Record 40 of Set 5 | calama
# Processing Record 41 of Set 5 | kurumkan
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | preobrazheniye
# Processing Record 44 of Set 5 | chhuikhadan
# Processing Record 45 of Set 5 | surovatikha
# Processing Record 46 of Set 5 | thompson
# Processing Record 47 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 5 | roald
# Processing Record 49 of Set 5 | tiksi
# Processing Record 50 of Set 5 | comodoro rivadavia
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | vilhena
# Processing Record 5 of Set 6 | the valley
# Processing Record 6 of Set 6 | namie
# Processing Record 7 of Set 6 | bandarbeyla
# Processing Record 8 of Set 6 | nelson bay
# Processing Record 9 of Set 6 | hollins
# Processing Record 10 of Set 6 | yar-sale
# Processing Record 11 of Set 6 | ulaanbaatar
# Processing Record 12 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 6 | teguldet
# Processing Record 14 of Set 6 | liku
# Processing Record 15 of Set 6 | nioro
# Processing Record 16 of Set 6 | kaohsiung
# Processing Record 17 of Set 6 | sungaipenuh
# Processing Record 18 of Set 6 | panormos
# Processing Record 19 of Set 6 | lillooet
# Processing Record 20 of Set 6 | ust-maya
# Processing Record 21 of Set 6 | east london
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | hede
# Processing Record 25 of Set 6 | lasa
# Processing Record 26 of Set 6 | aykhal
# Processing Record 27 of Set 6 | iralaya
# Processing Record 28 of Set 6 | rio tuba
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | nanortalik
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | jiaonan
# Processing Record 33 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 6 | salinas
# Processing Record 35 of Set 6 | katherine
# Processing Record 36 of Set 6 | sawtell
# Processing Record 37 of Set 6 | athmallik
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | cancun
# Processing Record 40 of Set 6 | muros
# Processing Record 41 of Set 6 | roma
# Processing Record 42 of Set 6 | hobyo
# Processing Record 43 of Set 6 | tigil
# Processing Record 44 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 45 of Set 6 | moranbah
# Processing Record 46 of Set 6 | wanaka
# Processing Record 47 of Set 6 | matveyevka
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | alofi
# Processing Record 50 of Set 6 | kargopol
# Processing Record 1 of Set 7 | araouane
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | porong
# Processing Record 4 of Set 7 | pangai
# Processing Record 5 of Set 7 | bowen
# Processing Record 6 of Set 7 | gawler
# Processing Record 7 of Set 7 | zhanaozen
# Processing Record 8 of Set 7 | mayskiy
# Processing Record 9 of Set 7 | nocera inferiore
# Processing Record 10 of Set 7 | kipini
# Processing Record 11 of Set 7 | mumford
# Processing Record 12 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 7 | pochutla
# Processing Record 14 of Set 7 | atar
# Processing Record 15 of Set 7 | medina del campo
# Processing Record 16 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 7 | fallon
# Processing Record 18 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | constitucion
# Processing Record 21 of Set 7 | salta
# Processing Record 22 of Set 7 | udachnyy
# Processing Record 23 of Set 7 | okhotsk
# Processing Record 24 of Set 7 | sisimiut
# Processing Record 25 of Set 7 | rocha
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | owando
# Processing Record 28 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 7 | pine bluff
# Processing Record 30 of Set 7 | silveira
# Processing Record 31 of Set 7 | codrington
# Processing Record 32 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | taltal
# Processing Record 35 of Set 7 | mahebourg
# Processing Record 36 of Set 7 | shenzhen
# Processing Record 37 of Set 7 | rio grande
# Processing Record 38 of Set 7 | cangzhou
# Processing Record 39 of Set 7 | poum
# Processing Record 40 of Set 7 | kampot
# Processing Record 41 of Set 7 | saint-martin-de-crau
# Processing Record 42 of Set 7 | masyaf
# Processing Record 43 of Set 7 | mpraeso
# Processing Record 44 of Set 7 | belmonte
# Processing Record 45 of Set 7 | tiznit
# Processing Record 46 of Set 7 | maha sarakham
# Processing Record 47 of Set 7 | odienne
# Processing Record 48 of Set 7 | esperanza
# Processing Record 49 of Set 7 | karratha
# Processing Record 50 of Set 7 | port arthur
# Processing Record 1 of Set 8 | buarcos
# Processing Record 2 of Set 8 | leh
# Processing Record 3 of Set 8 | gornyy
# Processing Record 4 of Set 8 | nemuro
# Processing Record 5 of Set 8 | usinsk
# Processing Record 6 of Set 8 | potosi
# Processing Record 7 of Set 8 | tura
# Processing Record 8 of Set 8 | winchester
# Processing Record 9 of Set 8 | port lincoln
# Processing Record 10 of Set 8 | frontignan
# Processing Record 11 of Set 8 | mecca
# Processing Record 12 of Set 8 | russell
# Processing Record 13 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 8 | kazanka
# Processing Record 15 of Set 8 | san clemente
# Processing Record 16 of Set 8 | rio cuarto
# Processing Record 17 of Set 8 | semme
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | nuuk
# Processing Record 20 of Set 8 | port moresby
# Processing Record 21 of Set 8 | falaleu
# City not found. Skipping...
# Processing Record 22 of Set 8 | mina
# Processing Record 23 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 24 of Set 8 | umm lajj
# Processing Record 25 of Set 8 | lensk
# Processing Record 26 of Set 8 | xining
# Processing Record 27 of Set 8 | yelizavetino
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | genhe
# Processing Record 30 of Set 8 | ugoofaaru
# Processing Record 31 of Set 8 | turayf
# Processing Record 32 of Set 8 | kadarkut
# Processing Record 33 of Set 8 | boddam
# Processing Record 34 of Set 8 | yeppoon
# Processing Record 35 of Set 8 | sao joao da barra
# Processing Record 36 of Set 8 | raudeberg
# Processing Record 37 of Set 8 | virginia beach
# Processing Record 38 of Set 8 | le port
# Processing Record 39 of Set 8 | qax
# Processing Record 40 of Set 8 | shelton
# Processing Record 41 of Set 8 | bulungu
# Processing Record 42 of Set 8 | sambava
# Processing Record 43 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 8 | kabale
# Processing Record 45 of Set 8 | hinton
# Processing Record 46 of Set 8 | los llanos de aridane
# Processing Record 47 of Set 8 | xiaoweizhai
# Processing Record 48 of Set 8 | akyab
# Processing Record 49 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | kichera
# Processing Record 2 of Set 9 | half moon bay
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | faanui
# Processing Record 5 of Set 9 | pastavy
# Processing Record 6 of Set 9 | sao vicente
# Processing Record 7 of Set 9 | fairlie
# Processing Record 8 of Set 9 | bonthe
# Processing Record 9 of Set 9 | kargasok
# Processing Record 10 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 11 of Set 9 | fort nelson
# Processing Record 12 of Set 9 | elizabeth city
# Processing Record 13 of Set 9 | flinders
# Processing Record 14 of Set 9 | althofen
# Processing Record 15 of Set 9 | beaumont
# Processing Record 16 of Set 9 | joao pinheiro
# Processing Record 17 of Set 9 | turukhansk
# Processing Record 18 of Set 9 | muhlhausen
# Processing Record 19 of Set 9 | charleville-mezieres
# Processing Record 20 of Set 9 | jambi
# Processing Record 21 of Set 9 | sri aman
# Processing Record 22 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 9 | hualmay
# Processing Record 26 of Set 9 | lazaro cardenas
# Processing Record 27 of Set 9 | znamenskoye
# Processing Record 28 of Set 9 | barranco
# Processing Record 29 of Set 9 | palaiokhora
# City not found. Skipping...
# Processing Record 30 of Set 9 | scottsbluff
# Processing Record 31 of Set 9 | ojinaga
# Processing Record 32 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 33 of Set 9 | lorengau
# Processing Record 34 of Set 9 | fonte boa
# Processing Record 35 of Set 9 | solwezi
# Processing Record 36 of Set 9 | xinmin
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | banda aceh
# Processing Record 39 of Set 9 | imperia
# Processing Record 40 of Set 9 | kibala
# Processing Record 41 of Set 9 | kimbe
# Processing Record 42 of Set 9 | prado
# Processing Record 43 of Set 9 | saint-leu
# Processing Record 44 of Set 9 | katobu
# Processing Record 45 of Set 9 | mulchen
# Processing Record 46 of Set 9 | kipushi
# Processing Record 47 of Set 9 | insar
# Processing Record 48 of Set 9 | sao filipe
# Processing Record 49 of Set 9 | talnakh
# Processing Record 50 of Set 9 | mayya
# Processing Record 1 of Set 10 | pasighat
# Processing Record 2 of Set 10 | hurghada
# Processing Record 3 of Set 10 | opunake
# Processing Record 4 of Set 10 | saint-michel-des-saints
# Processing Record 5 of Set 10 | kualakapuas
# Processing Record 6 of Set 10 | yarada
# Processing Record 7 of Set 10 | dudinka
# Processing Record 8 of Set 10 | razole
# Processing Record 9 of Set 10 | mahon
# Processing Record 10 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 11 of Set 10 | beaver falls
# Processing Record 12 of Set 10 | awbari
# Processing Record 13 of Set 10 | ponta delgada
# Processing Record 14 of Set 10 | matay
# Processing Record 15 of Set 10 | tabuk
# Processing Record 16 of Set 10 | sobolevo
# Processing Record 17 of Set 10 | kinablangan
# Processing Record 18 of Set 10 | isla mujeres
# Processing Record 19 of Set 10 | zhigansk
# Processing Record 20 of Set 10 | grenfell
# Processing Record 21 of Set 10 | setermoen
# Processing Record 22 of Set 10 | mantua
# Processing Record 23 of Set 10 | houston
# Processing Record 24 of Set 10 | kedgwick
# Processing Record 25 of Set 10 | severo-yeniseyskiy
# Processing Record 26 of Set 10 | port hedland
# Processing Record 27 of Set 10 | touros
# Processing Record 28 of Set 10 | deputatskiy
# Processing Record 29 of Set 10 | hargeysa
# Processing Record 30 of Set 10 | tianpeng
# Processing Record 31 of Set 10 | villa oliva
# City not found. Skipping...
# Processing Record 32 of Set 10 | tanout
# Processing Record 33 of Set 10 | bogorodskoye
# Processing Record 34 of Set 10 | altay
# Processing Record 35 of Set 10 | laredo
# Processing Record 36 of Set 10 | fairbanks
# Processing Record 37 of Set 10 | geraldton
# Processing Record 38 of Set 10 | woodend
# Processing Record 39 of Set 10 | baijiantan
# Processing Record 40 of Set 10 | pacific grove
# Processing Record 41 of Set 10 | olinda
# Processing Record 42 of Set 10 | oxford
# Processing Record 43 of Set 10 | lang suan
# Processing Record 44 of Set 10 | dwarka
# Processing Record 45 of Set 10 | riyadh
# Processing Record 46 of Set 10 | chibuto
# Processing Record 47 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | viedma
# Processing Record 50 of Set 10 | camacupa
# Processing Record 1 of Set 11 | omboue
# Processing Record 2 of Set 11 | port blair
# Processing Record 3 of Set 11 | thinadhoo
# Processing Record 4 of Set 11 | marovoay
# Processing Record 5 of Set 11 | yakeshi
# Processing Record 6 of Set 11 | barranca
# Processing Record 7 of Set 11 | cabo san lucas
# Processing Record 8 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 9 of Set 11 | takaka
# Processing Record 10 of Set 11 | husavik
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | abha
# Processing Record 13 of Set 11 | la ronge
# Processing Record 14 of Set 11 | ayan
# Processing Record 15 of Set 11 | casa nova
# Processing Record 16 of Set 11 | kamyaran
# Processing Record 17 of Set 11 | cristobal obregon
# Processing Record 18 of Set 11 | ahuimanu
# Processing Record 19 of Set 11 | acari
# Processing Record 20 of Set 11 | selikhino
# Processing Record 21 of Set 11 | puerto cabello
# Processing Record 22 of Set 11 | eureka
# Processing Record 23 of Set 11 | haikou
# Processing Record 24 of Set 11 | kokopo
# Processing Record 25 of Set 11 | alekseyevsk
# Processing Record 26 of Set 11 | goias
# Processing Record 27 of Set 11 | belaya gora
# Processing Record 28 of Set 11 | tarakan
# Processing Record 29 of Set 11 | rosendal
# Processing Record 30 of Set 11 | majene
# Processing Record 31 of Set 11 | panguipulli
# Processing Record 32 of Set 11 | itoman
# Processing Record 33 of Set 11 | buraydah
# Processing Record 34 of Set 11 | peabiru
# Processing Record 35 of Set 11 | paraiso
# Processing Record 36 of Set 11 | palmer
# Processing Record 37 of Set 11 | almaznyy
# Processing Record 38 of Set 11 | ouallam
# Processing Record 39 of Set 11 | keffi
# Processing Record 40 of Set 11 | rassvet
# Processing Record 41 of Set 11 | pathein
# Processing Record 42 of Set 11 | henties bay
# Processing Record 43 of Set 11 | oktyabrskiy
# Processing Record 44 of Set 11 | neiafu
# Processing Record 45 of Set 11 | sturgis
# Processing Record 46 of Set 11 | koungou
# Processing Record 47 of Set 11 | doha
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 11 | luderitz
# Processing Record 1 of Set 12 | snyder
# Processing Record 2 of Set 12 | fort wellington
# Processing Record 3 of Set 12 | itarema
# Processing Record 4 of Set 12 | pingliang
# Processing Record 5 of Set 12 | beira
# Processing Record 6 of Set 12 | sundsvall
# Processing Record 7 of Set 12 | leicester
# Processing Record 8 of Set 12 | taonan
# Processing Record 9 of Set 12 | springdale
# Processing Record 10 of Set 12 | sretensk
# Processing Record 11 of Set 12 | qaqortoq
# Processing Record 12 of Set 12 | calella
# Processing Record 13 of Set 12 | pacasmayo
# Processing Record 14 of Set 12 | manta
# Processing Record 15 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 12 | cosala
# Processing Record 17 of Set 12 | shache
# Processing Record 18 of Set 12 | mersing
# Processing Record 19 of Set 12 | parana
# Processing Record 20 of Set 12 | nieuw amsterdam
# Processing Record 21 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 12 | eyl
# Processing Record 23 of Set 12 | akcakoca
# Processing Record 24 of Set 12 | zarasai
# Processing Record 25 of Set 12 | konstantinovka
# Processing Record 26 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 12 | sydney
# Processing Record 28 of Set 12 | severobaykalsk
# Processing Record 29 of Set 12 | dongtai
# Processing Record 30 of Set 12 | ponazyrevo
# Processing Record 31 of Set 12 | walvis bay
# Processing Record 32 of Set 12 | vanimo
# Processing Record 33 of Set 12 | wanlaweyn
# Processing Record 34 of Set 12 | saint-denis
# Processing Record 35 of Set 12 | tanabe
# Processing Record 36 of Set 12 | gemena
# Processing Record 37 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 12 | dickinson
# Processing Record 39 of Set 12 | viransehir
# Processing Record 40 of Set 12 | pangkalanbuun
# Processing Record 41 of Set 12 | lianzhou
# Processing Record 42 of Set 12 | rodrigues alves
# Processing Record 43 of Set 12 | opuwo
# Processing Record 44 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 12 | maloy
# Processing Record 46 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 47 of Set 12 | cabedelo
# Processing Record 48 of Set 12 | adrar
# Processing Record 49 of Set 12 | nelipyno
# Processing Record 50 of Set 12 | ostersund
# Processing Record 1 of Set 13 | wiarton
# Processing Record 2 of Set 13 | amahai
# Processing Record 3 of Set 13 | champerico
# Processing Record 4 of Set 13 | broome
# Processing Record 5 of Set 13 | tselinnoye
# Processing Record 6 of Set 13 | nhamunda
# Processing Record 7 of Set 13 | brownwood
# Processing Record 8 of Set 13 | wajir
# Processing Record 9 of Set 13 | dunedin
# Processing Record 10 of Set 13 | taikang
# Processing Record 11 of Set 13 | gayeri
# Processing Record 12 of Set 13 | bougouni
# Processing Record 13 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 13 | nautla
# Processing Record 15 of Set 13 | sukhumi
# Processing Record 16 of Set 13 | kultuk
# Processing Record 17 of Set 13 | dongying
# Processing Record 18 of Set 13 | goshen
# Processing Record 19 of Set 13 | atambua
# Processing Record 20 of Set 13 | aksu
# Processing Record 21 of Set 13 | mithimna
# City not found. Skipping...
# Processing Record 22 of Set 13 | rehoboth
# Processing Record 23 of Set 13 | parabel
# Processing Record 24 of Set 13 | pinsk
# Processing Record 25 of Set 13 | san francisco
# Processing Record 26 of Set 13 | sibolga
# Processing Record 27 of Set 13 | mount isa
# Processing Record 28 of Set 13 | niquelandia
# Processing Record 29 of Set 13 | flin flon
# Processing Record 30 of Set 13 | rincon
# Processing Record 31 of Set 13 | carballo
# Processing Record 32 of Set 13 | abomey
# Processing Record 33 of Set 13 | maniitsoq
# Processing Record 34 of Set 13 | quthing
# Processing Record 35 of Set 13 | karwar
# Processing Record 36 of Set 13 | aginskoye
# Processing Record 37 of Set 13 | haines junction
# Processing Record 38 of Set 13 | kiomboi
# Processing Record 39 of Set 13 | ust-ilimsk
# Processing Record 40 of Set 13 | zyryanka
# Processing Record 41 of Set 13 | hrubieszow
# Processing Record 42 of Set 13 | pitimbu
# Processing Record 43 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 13 | kutum
# Processing Record 45 of Set 13 | fairview
# Processing Record 46 of Set 13 | nidzica
# Processing Record 47 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 13 | upata
# Processing Record 49 of Set 13 | agadez
# Processing Record 50 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | olga
# Processing Record 3 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 4 of Set 14 | waipawa
# Processing Record 5 of Set 14 | saint-georges
# Processing Record 6 of Set 14 | lenoir
# Processing Record 7 of Set 14 | krasnoselkup
# Processing Record 8 of Set 14 | sao miguel do araguaia
# Processing Record 9 of Set 14 | kamaishi
# Processing Record 10 of Set 14 | bosaso
# Processing Record 11 of Set 14 | nogliki
# Processing Record 12 of Set 14 | oktyabrskoye
# Processing Record 13 of Set 14 | rawson
# Processing Record 14 of Set 14 | chara
# Processing Record 15 of Set 14 | xinqing
# Processing Record 16 of Set 14 | albacete
# Processing Record 17 of Set 14 | praia
# Processing Record 18 of Set 14 | agbor
# Processing Record 19 of Set 14 | tibati
# Processing Record 20 of Set 14 | maiduguri
# Processing Record 21 of Set 14 | namatanai
# Processing Record 22 of Set 14 | matagami
# Processing Record 23 of Set 14 | te anau
# Processing Record 24 of Set 14 | port keats
# Processing Record 25 of Set 14 | trairi
# Processing Record 26 of Set 14 | urengoy
# Processing Record 27 of Set 14 | akdepe
# Processing Record 28 of Set 14 | horodyshche
# Processing Record 29 of Set 14 | woodstock
# Processing Record 30 of Set 14 | la rochelle
# Processing Record 31 of Set 14 | salou
# Processing Record 32 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 14 | acarau
# Processing Record 34 of Set 14 | launceston
# Processing Record 35 of Set 14 | togur
# Processing Record 36 of Set 14 | micheweni
# Processing Record 37 of Set 14 | havre-saint-pierre
# Processing Record 38 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 14 | matara
# Processing Record 40 of Set 14 | belorechensk
# Processing Record 41 of Set 14 | hofn
# Processing Record 42 of Set 14 | portland
# Processing Record 43 of Set 14 | ruidoso
# Processing Record 44 of Set 14 | truckee
# Processing Record 45 of Set 14 | nevyansk
# Processing Record 46 of Set 14 | alpena
# Processing Record 47 of Set 14 | riberalta
# Processing Record 48 of Set 14 | darhan
# Processing Record 49 of Set 14 | reyes
# Processing Record 50 of Set 14 | mehamn
# Processing Record 1 of Set 15 | ahipara
# Processing Record 2 of Set 15 | cascais
# Processing Record 3 of Set 15 | kologriv
# Processing Record 4 of Set 15 | beisfjord
# Processing Record 5 of Set 15 | burns lake
# Processing Record 6 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 7 of Set 15 | luan
# Processing Record 8 of Set 15 | grimshaw
# Processing Record 9 of Set 15 | moose factory
# Processing Record 10 of Set 15 | ulladulla
# Processing Record 11 of Set 15 | bell ville
# Processing Record 12 of Set 15 | botro
# Processing Record 13 of Set 15 | ambulu
# Processing Record 14 of Set 15 | kizhinga
# Processing Record 15 of Set 15 | luanda
# Processing Record 16 of Set 15 | muroto
# Processing Record 17 of Set 15 | ambon
# Processing Record 18 of Set 15 | blairmore
# Processing Record 19 of Set 15 | seguin
# Processing Record 20 of Set 15 | anchorage
# Processing Record 21 of Set 15 | kenai
# Processing Record 22 of Set 15 | west wendover
# Processing Record 23 of Set 15 | olafsvik
# Processing Record 24 of Set 15 | candido mendes
# Processing Record 25 of Set 15 | oranjestad
# Processing Record 26 of Set 15 | zhicheng
# Processing Record 27 of Set 15 | abalak
# Processing Record 28 of Set 15 | ostrovnoy
# Processing Record 29 of Set 15 | huilong
# Processing Record 30 of Set 15 | kulhudhuffushi
# Processing Record 31 of Set 15 | palestine
# Processing Record 32 of Set 15 | taseyevo
# Processing Record 33 of Set 15 | makaha
# Processing Record 34 of Set 15 | mayumba
# Processing Record 35 of Set 15 | takoradi
# Processing Record 36 of Set 15 | phayakkhaphum phisai
# Processing Record 37 of Set 15 | tazovskiy
# Processing Record 38 of Set 15 | roswell
# Processing Record 39 of Set 15 | nakamura
# Processing Record 40 of Set 15 | ochamchira
# Processing Record 41 of Set 15 | kupang
# Processing Record 42 of Set 15 | samarai
# Processing Record 43 of Set 15 | quelimane
# Processing Record 44 of Set 15 | belin
# Processing Record 45 of Set 15 | gigmoto
# Processing Record 46 of Set 15 | yatou
# Processing Record 47 of Set 15 | iquique
# Processing Record 48 of Set 15 | xadani
# City not found. Skipping...
# Processing Record 49 of Set 15 | orlik
# Processing Record 50 of Set 15 | severnoye
# Processing Record 1 of Set 16 | bathsheba
# Processing Record 2 of Set 16 | abu dhabi
# Processing Record 3 of Set 16 | valladolid
# Processing Record 4 of Set 16 | plettenberg bay
# Processing Record 5 of Set 16 | hammond
# Processing Record 6 of Set 16 | kimberley
# Processing Record 7 of Set 16 | manokwari
# Processing Record 8 of Set 16 | pochinok
# Processing Record 9 of Set 16 | kiunga
# Processing Record 10 of Set 16 | mackenzie
# Processing Record 11 of Set 16 | hirtshals
# Processing Record 12 of Set 16 | ulaangom
# Processing Record 13 of Set 16 | khandyga
# -------------------------
# Data Retrieval Complete
# -------------------------
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Daru  -9.0763  143.2092     79.03        87         100       16.91
# 1    Ushuaia -54.8000  -68.3000     51.46        66          40        6.91
# 2  Ilulissat  69.2167  -51.1000     30.22        47          20        6.91
# 3     Barrow  71.2906 -156.7887     30.22        74          90        5.75
# 4    Cangucu -31.3950  -52.6756     61.81        86         100       10.49
#
#   Country Current Description
# 0      PG     overcast clouds
# 1      AR          light rain
# 2      GL          few clouds
# 3      US     overcast clouds
# 4      BR     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Daru      PG  -9.0763  143.2092     79.03        87         100
# 1    Ushuaia      AR -54.8000  -68.3000     51.46        66          40
# 2  Ilulissat      GL  69.2167  -51.1000     30.22        47          20
# 3     Barrow      US  71.2906 -156.7887     30.22        74          90
# 4    Cangucu      BR -31.3950  -52.6756     61.81        86         100
#
#    Wind Speed Current Description
# 0       16.91     overcast clouds
# 1        6.91          light rain
# 2        6.91          few clouds
# 3        5.75     overcast clouds
# 4       10.49     overcast clouds

# %%
# Create output file (CSV).
output_data_file = '/Users/mikequick/Documents/DU Data Boot Camp/Module 6 - WeatherPy/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv'

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City ID')
